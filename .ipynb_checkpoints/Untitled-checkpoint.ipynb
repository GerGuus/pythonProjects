# %%
06.04.23, © Іващенко Артем КІ-20-1, 2023
Лабораторна робота №1.
Тема: Інсталяція та налаштування Python-середовища
Мета: quick start для роботи з python3 у середовищі IDE PyCharm системою контроля версій git.

1.Завантажив і встановив Python.
2.Завантажив, встановив і налаштував IDE PyCharm у відповідності з інструкціями.
3.Завантажив, встановив і налаштував систему контроля версій Git на робочому комп'ютері.
4.Створив акаунт на GitHub та стоврив в ньому новий проєкт з іменем pythonProject.
5.Налаштував зв'язок PyCharm з Git.
6.Налаштував зв'язок PyCharm з віддаленим репозиторієм на GitHub.
7.Створив файл lab_1_Samarec.py з кодом, який виводить фразу "Hi, GerGus"



8.Закомітив файл у локальний репозиторій.
9.Відправив ("запушити") поточну версію Git-проєкта у віддалений репозиторій на GitHub.

Посилання на репозиторій
Контрольні запитання
У чому відмінність інтерпретатора від компілятора? Python - компілятор чи інтерпретатор? Компілятор повністю перетворює початковий код програми в машинний, який операційна система може виконати самостійно. Python може бути визначений як інтерпретатор та компілятор, оскільки він компілює код Python у байт-код перед його інтерпретацією.

Що таке IDE PyCharm? PyCharm — інтегроване середовище розробки для мови програмування Python

Що таке система контроля версій (СКВ) і для чого вона призначена? У чому принципова відмінність СКВ svn та git? Система керування версіями (СКВ, англ. source code management, SCM) — програмний інструмент для керування версіями одиниці інформації: початкового коду програми, скрипту, вебсторінки, вебсайту, 3D-моделі, текстового документу тощо. SVN налаштований так, що передбачається, що журнал проекту ніколи не змінюється. Git дозволяє змінювати попередні фіксації та зміни за допомогою таких засобів як git rebase.

Що відбувається при виконанні команди git add .? Команда git add додає зміну з робочого каталогу до розділу проіндексованих файлів

Що відбувається при виконанні команди git commit? Команда git add додає вміст робочого каталогу до індексу (staging area) для наступного комміту

Якою git-командою виконується розміщення локальної копії git-репозиторію проєкта на віддаленому, що знаходиться на GitHub? git clone
